# %%
#import sklearn.datasets.fetch_california_housing
import numpy as np
from sklearn import datasets
#import plotly as py

cal_hou = datasets.fetch_california_housing()

# %%
import pandas as pd
df = pd.DataFrame(data=cal_hou['data'], columns=cal_hou['feature_names']) 
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# 25%        2.429741     33.930000   -121.800000
# 50%        2.818116     34.260000   -118.490000
# 75%        3.282261     37.710000   -118.010000
# max     1243.333333     41.950000   -114.310000

# %%
aux = cal_hou['feature_names'].copy()
aux.remove('Latitude')
aux.remove('Longitude')
cal_hou['feature_names'] = aux
print(aux)
data_aux = cal_hou['data'].copy()
data_aux = np.delete(data_aux,6,1)
data_aux = np.delete(data_aux,6,1)
#data_aux
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup']

# %% [markdown]
# Eliminamos latitud y longitud.

# %%
df = pd.DataFrame(data=data_aux, columns=aux) 
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup
# count  20640.000000
# mean       3.070655
# std       10.386050
# min        0.692308
# 25%        2.429741
# 50%        2.818116
# 75%        3.282261
# max     1243.333333

# %%
import collections
import operator
print(df['MedInc'][87])
medinc = sorted(df['MedInc'].items(), key=lambda kv: kv[1])
l = len(medinc)
print(l)
for x in range(0,l):
    a,b = medinc[x]
    medinc[x] = (x,b)
#print(medinc)
medincmap = dict(medinc)
#medincmap.values().head()
# Out:
# 0.76
# 20640

# %%
df2 = df.copy()
df2['MedIncOrd'] = sorted(df['MedInc'].values)

# %%
# Definición de una función
def clasificarDF2(x):
    if x < 3:
        return 'baja'
    elif x < 7:
        return 'media'
    else:
        return 'alta'

# %%
from pandas.plotting import scatter_matrix

dic_colors = { 'baja': 'red', 'media': 'orange', 'alta': 'green' }
colors = df2['MedIncOrd'].map(clasificarDF2).map(dic_colors)

# %%
scatter_matrix(df, figsize = (12, 12), diagonal = 'hist', color=colors)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C243F88A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C243FF4CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244029198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244051828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244079EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244079EF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2440CEC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2440FF2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244125978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244157048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2441816D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2441A5D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2441D7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244200AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244232198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244257828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244280EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2442B2588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2442D8C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24430B2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244332978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244364048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2443896D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2443B3D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2443E2438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24440BAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24443C198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C244465828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24448BEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2444BB588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2444E2C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2445142E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24453A978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24456D048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2445966D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2445BCD68>]],
#       dtype=object)

# %%
#normalizamos los datos:

from sklearn.preprocessing import Normalizer

# Normalizamos los datos para que estén centrados en 0 y con varianza 1
scaler = Normalizer()
df_values_normal = scaler.fit_transform(df.values)
df_normal = pd.DataFrame(data=df_values_normal, columns=cal_hou['feature_names']) 
df_normal.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       0.004889      0.037450      0.007642      0.001568      0.996317
# std        0.010754      0.063291      0.024530      0.005466      0.032200
# min        0.000072      0.000184      0.000148      0.000028      0.151008
# 25%        0.001760      0.012447      0.002837      0.000610      0.999037
# 50%        0.003000      0.023976      0.004438      0.000903      0.999684
# 75%        0.005021      0.042432      0.006918      0.001343      0.999906
# max        0.406675      0.981552      0.939911      0.233944      1.000000
#
#            AveOccup
# count  20640.000000
# mean       0.003642
# std        0.007830
# min        0.000164
# 25%        0.001653
# 50%        0.002442
# 75%        0.003571
# max        0.413359

# %%
scatter_matrix(df_normal, figsize = (12, 12), diagonal = 'hist', color=colors)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C247E0E470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247E67940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247E8FFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247EC16A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247EE8D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247EE8D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C247F44A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247F75160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247F9D7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247FC5E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C247FF7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C248021BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2480512B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C248079940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2480A1FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2480D26A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2480FBD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24812E400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C248155A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C248189128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2481AF7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2481D8E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24820B518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C248232BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C248264278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24828B908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2482B5F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2482E5668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24830DCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2483403C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C248369A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24839A128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2483BF7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2483E9E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24841D518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C248444BA8>]],
#       dtype=object)

# %%
df2=df.copy().loc[df.AveBedrms<15]
len(df2)
scatter_matrix(df2, figsize = (12, 12), diagonal = 'hist', color=colors)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2484954E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CC79240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CC9AAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C6F0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C719828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C719860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C772588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C799C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C7C4FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C7F66A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C81CD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C84F400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C877A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C8A8160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C8D07B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C8FBE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C92A518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C953BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C24C986278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CCBD908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CCE5F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CD15668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CD3ECF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CD6E3C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CD98A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CDCC128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CDF37B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CE1BE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CE4C518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CE74BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CEA6278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CECE908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CEF8F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CF29668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CF51CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C24CF813C8>]],
#       dtype=object)

# %%
#Como la edad de la csa y la poblacion están correlacionados, consideramos que podemos prescindir de un de estos dos datos
data_aux2 = np.delete(data_aux,2,1)
aux.remove('AveBedrms')
df_def = pd.DataFrame(data=data_aux2, columns=aux) 
df_def.describe()
# Out:
#              MedInc      HouseAge      AveRooms    Population      AveOccup
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      1.096675   1425.476744      3.070655
# std        1.899822     12.585558      0.473911   1132.462122     10.386050
# min        0.499900      1.000000      0.333333      3.000000      0.692308
# 25%        2.563400     18.000000      1.006079    787.000000      2.429741
# 50%        3.534800     29.000000      1.048780   1166.000000      2.818116
# 75%        4.743250     37.000000      1.099526   1725.000000      3.282261
# max       15.000100     52.000000     34.066667  35682.000000   1243.333333

# %%
# Estandarizamos los datos para que estén centrados en 0 y con varianza 1

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_values_std = scaler.fit_transform(df_def.values)
df_std = pd.DataFrame(data=df_values_std, columns=cal_hou['feature_names']) 
df_std.describe()
# Out:
#              MedInc      HouseAge      AveRooms    Population      AveOccup
# count  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04
# mean  -2.522018e-14  5.878911e-16  5.519526e-15 -7.506747e-17 -7.361326e-16
# std    1.000024e+00  1.000024e+00  1.000024e+00  1.000024e+00  1.000024e+00
# min   -1.774299e+00 -2.196180e+00 -1.610768e+00 -1.256123e+00 -2.290000e-01
# 25%   -6.881186e-01 -8.453931e-01 -1.911716e-01 -5.638089e-01 -6.171062e-02
# 50%   -1.767951e-01  2.864572e-02 -1.010650e-01 -2.291318e-01 -2.431585e-02
# 75%    4.593063e-01  6.643103e-01  6.015869e-03  2.644949e-01  2.037453e-02
# max    5.858286e+00  1.856182e+00  6.957171e+01  3.025033e+01  1.194191e+02

# %%
scatter_matrix(df_std, figsize = (12, 12), diagonal = 'hist', color=colors)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2504E8898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25076D438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C250782748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2501E3A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25020BD68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C25020BDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2502693C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2502926A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2502BC9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2502E7CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C250310FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C250344320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C250370630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C250397940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2503C4C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2503EDF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2504202B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25044A5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2504738D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25049DBE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2507C9EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2507F5B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2508281D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25084F860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C250876EF0>]],
#       dtype=object)

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.datasets.samples_generator import make_blobs
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.colors import ListedColormap
import numpy as np

np.random.seed(7)
#plot_clusters(df_normal, labels, centers)

# %%
K_MAX = 8
silueta = np.zeros(K_MAX-2)
for k in range(2, K_MAX): 
    km1 = KMeans(init='random', n_clusters=k)
    km1.fit(df_normal)
    #plot_clusters(X, km.labels_, km.cluster_centers_)
    
    silueta[k-2] = silhouette_score(df_normal, km1.labels_) 
plt.plot(range(2, K_MAX), silueta)
plt.title('Valor de silueta para diferentes k')
# Out:
# Text(0.5,1,'Valor de silueta para diferentes k')

# %%
K_MAX = 8
silueta2 = np.zeros(K_MAX-2)
for k in range(2, K_MAX): 
    km2 = KMeans(init='random', n_clusters=k)
    km2.fit(df_std)
    #plot_clusters(X, km.labels_, km.cluster_centers_)
    
    silueta2[k-2] = silhouette_score(df_std, km2.labels_) 
plt.plot(range(2, K_MAX), silueta2)
plt.title('Valor de silueta para diferentes k')
# Out:
# Text(0.5,1,'Valor de silueta para diferentes k')

# %%
km_normal = KMeans(init='random', n_clusters=2)

# Agrupar los puntos en clusters
km_normal.fit(df_normal)

# Podemos consultar el cluster asignado a cada punto y el centro de cada cluster
labels_normal = km_normal.labels_
centers_normal = km_normal.cluster_centers_

# %%
km_std = KMeans(init='random', n_clusters=5)

# Agrupar los puntos en clusters
km_std.fit(df_std)

# Podemos consultar el cluster asignado a cada punto y el centro de cada cluster
labels_std = km_std.labels_
centers_std = km_std.cluster_centers_

# %%
dic_colors = { 0: 'blue', 1: 'red', 2: 'yellow', 3 : 'green', 4: 'orange', 5:'purple', 6:'black'}
df_normal['grupo']=labels_normal
colors_normal=df_normal['grupo'].map(dic_colors)
scatter_matrix(df_normal, figsize = (12, 12), diagonal = 'hist', color=colors_normal)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2590DAA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2590B6C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2596C58D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2596DEBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25911FEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25911FF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C259177550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2591A2BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2591D32B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2591FB940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C259223FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2592536A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25927CD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2592AD400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C2592D6A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25930A160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2593317B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C259358E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25938A518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2593B1BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A6D3278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A6FD908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A723F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A756668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A77ECF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A7B03C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A7D7A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A80B128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A8317B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A85AE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A88A518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A8B5BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A8E7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A90D908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A938F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A969668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A98FCF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A9C23C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25A9EAA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AA1E128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AA447B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AA6DE48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AA9E518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AAC6BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AAF6278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AB20908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AB46F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25AB79668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C25ABA3CF8>]],
#       dtype=object)

# %%
df_std['grupo']=labels_std
colors_std=df_std['grupo'].map(dic_colors)
scatter_matrix(df_std, figsize = (12, 12), diagonal = 'hist', color=colors_std)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C26176DFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261CBBCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261CDC080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C26178F710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2617BADA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2617BADD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C261811B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2618461D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C26186C860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261896EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2618C75C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2618F0C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C261920320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2619489B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C26197B080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2619A4710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2619CBD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C2619FD438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C261A25AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261D07198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261D30828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261D58EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261D8A588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261DB1C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C261DE32E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261E09978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261E3D048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261E666D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261E8DD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261EBF438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C261EE5AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261F18198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261F41828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261F69EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261F9C588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C261FC6C18>]],
#       dtype=object)
